# %%
import sys
import numpy as np
import pandas as pd

print("Python executable:", sys.executable)
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
# Out:
# Python executable: d:\conda_envs\rithi_env\python.exe
# NumPy version: 2.2.6
# Pandas version: 2.3.3
